# %% [markdown]
# This is my analysis of Riverkeeper (www.riverkeeper.org) data on Hudson River Enterococcus levels

# %% [markdown]
# First I load data and libraries:

# %%
import pandas as p
from ggplot import *

# %%
river_entero = p.read_csv('data/riverkeeper_data_2013.csv')

# %% [markdown]
# Let's look at the data:

# %%
river_entero[0:5]
# Out:
#                         Site        Date EnteroCount  FourDayRainTotal  \
# 0  Hudson above Mohawk River  10/16/2011        1733               1.5
# 1  Hudson above Mohawk River  10/21/2013           4               0.2
# 2  Hudson above Mohawk River   9/21/2013          20               0.0
# 3  Hudson above Mohawk River   8/19/2013           6               0.0
# 4  Hudson above Mohawk River   7/21/2013          31               0.0
#
#    SampleCount
# 0           35
# 1           35
# 2           35
# 3           35
# 4           35
#
# [5 rows x 5 columns]

# %%
river_entero.describe()
# Out:
#        FourDayRainTotal  SampleCount
# count       3397.000000  3397.000000
# mean           0.568001    56.886370
# std            1.000387    41.588476
# min            0.000000    27.000000
# 25%            0.000000    37.000000
# 50%            0.200000    42.000000
# 75%            0.700000    50.000000
# max            8.500000   187.000000
#
# [8 rows x 2 columns]

# %% [markdown]
# uh oh: python is not recognizing EnteroCount as a numeric field
# ! Let's fix that

# %%
river_entero['Date'] = p.Series([p.to_datetime(d) for d in river_entero['Date']])

# %% [markdown]
# let's find this bad data

# %%
river_entero['EnteroCount'].value_counts()
# Out:
# <10      528
# 10       289
# 20       148
# 2         83
# 4         78
# 3         77
# 1         77
# 31        65
# 41        64
# 6         64
# 5         63
# >2420     59
# 11        59
# 12        50
# 7         47
# ...
# 280     1
# 400     1
# 2400    1
# 404     1
# 939     1
# 288     1
# 138     1
# 4229    1
# 479     1
# 131     1
# 1785    1
# 760     1
# 763     1
# 762     1
# 137     1
# Length: 425, dtype: int64

# %% [markdown]
# Ok- it looks like there are four bad values: <1,<10, >2420, >24196. We want to adjust them. What should we do? Well: that is tricky. <1 is easy. For <10, we know that the value is bounded 0-10, so one approach would be to randomly select numbers 0-10 (if we were really careful, we could estimate the relative frequency).
#
# For >2420, that is a tougher questions. let's look at what the distribution of >2420 readings looks like:

# %%
tmp = river_entero.copy()
tmp['EnteroCount'].replace(to_replace='<1', value=0, inplace=True)
tmp['EnteroCount'].replace(to_replace='<10', value=0, inplace=True)
tmp['EnteroCount'].replace(to_replace='>2420', value=0, inplace=True)
tmp['EnteroCount'].replace(to_replace='>24196', value=0, inplace=True)
tmp = tmp[tmp['EnteroCount'].astype('float') > 2420]

# %%
tmp.describe()
# Out:
#        FourDayRainTotal  SampleCount
# count         34.000000    34.000000
# mean           1.197059    80.852941
# std            1.494533    60.875498
# min            0.000000    27.000000
# 25%            0.300000    42.000000
# 50%            0.950000    49.000000
# 75%            1.575000   138.000000
# max            6.400000   187.000000
#
# [8 rows x 2 columns]

# %%
tmp['EnteroCount']=tmp['EnteroCount'].convert_objects(convert_numeric=True)
ggplot(tmp,aes(x='EnteroCount')) + geom_histogram(binwidth=500) + xlim(2400, 5000) + ylim(0,100)
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# <ggplot: (277429937)>

# %% [markdown]
# Looks like putting in 3000-4500 is a pretty decent proxy for the rest of our data (though it looks like people just wrote '3000' for high values: probably deserves some more investigation. Let's put in 3750 for now though.

# %%
import random
river_entero['EnteroCount'].replace(to_replace='<1', value=0, inplace=True)

river_entero['EnteroCount'].replace(to_replace='<10', value=int(10*random.random()), inplace=True)
river_entero['EnteroCount'].replace(to_replace='>2420', value=3750, inplace=True)

# %%
river_entero['EnteroCount'] = river_entero['EnteroCount'].convert_objects(convert_numeric=True)

# %%
river_entero.describe()
# Out:
#         EnteroCount  FourDayRainTotal  SampleCount
# count   3377.000000       3397.000000  3397.000000
# mean     269.343500          0.568001    56.886370
# std      982.455367          1.000387    41.588476
# min        0.000000          0.000000    27.000000
# 25%        6.000000          0.000000    37.000000
# 50%       18.000000          0.200000    42.000000
# 75%       83.000000          0.700000    50.000000
# max    24196.000000          8.500000   187.000000
#
# [8 rows x 3 columns]

# %% [markdown]
# Ok, let's make some graphs - Let's start with an initial chart to see what we are dealing with

# %%
ggplot(river_entero, aes(x='Date', y='EnteroCount')) + \
geom_point(alpha=.5, color='red') + stat_smooth(span=.15, color='black', se=True) + \
ggtitle('All Enterococcus Counts by Day') + ylim(0, 10000)
# Out:
# <ggplot: (277429785)>

# %% [markdown]
# # 1. Create lists & graphs of the best and worst places to swim in the dataset.

# %% [markdown]
# Given that a single reading over 32 is considered unsafe, we have a really high likelihood of finding locations that do not pass health inspection!
#
# 'Best' and 'Worst' are subjective labels. To me, it means that you are *most likely* to have poor conditions that prevent swimming, not that you swim in the absolute lowest quality water. I'm going to look at the likelihood of passing/failing the test, though other methods are ok as well. I'm also only going to look at the past 3 years: an arbitrary cut-off, but I do not think data from 2007 has much importance now.

# %%
from datetime import datetime
river_entero['pass_safety'] = river_entero['EnteroCount'] <= 110

# %%
river_entero[0:3]
# Out:
#                         Site                Date  EnteroCount  \
# 0  Hudson above Mohawk River 2011-10-16 00:00:00         1733
# 1  Hudson above Mohawk River 2013-10-21 00:00:00            4
# 2  Hudson above Mohawk River 2013-09-21 00:00:00           20
#
#    FourDayRainTotal  SampleCount pass_safety
# 0               1.5           35       False
# 1               0.2           35        True
# 2               0.0           35        True
#
# [3 rows x 6 columns]

# %%
site_pass_rate = river_entero[['Site', 'pass_safety', 'EnteroCount']][river_entero['Date'] >= datetime(2011,01,01)].groupby('Site').mean()

# %% [markdown]
# Ok, we have our pass rates.
#
# *For the WORST* let's take the places with the lowest pass rates first, and break ties with the highest average Entero counts first.
# *For the BEST* we will do the opposite

# %%
worst = site_pass_rate.sort(['pass_safety','EnteroCount'], ascending=[1,0])[0:7]

# %%
worst[:]
# Out:
#                                          pass_safety  EnteroCount
# Site
# Upper Sparkill Creek                        0.166667  1659.333333
# Mohawk River at Waterford                   0.277778   823.500000
# Newburgh Launch Ramp                        0.444444   348.388889
# Dunn Memorial Bridge- Albany                0.500000   532.277778
# Saw Mill River                              0.526316  1584.888889
# Newtown Creek- Metropolitan Ave. Bridge     0.578947   563.947368
# North River STP at 145th                    0.578947   443.263158
#
# [7 rows x 2 columns]

# %%
best = site_pass_rate.sort(['pass_safety','EnteroCount'], ascending=[0,1])[0:8]

# %%
best[:]
# Out:
#                                     pass_safety  EnteroCount
# Site
# TZ Bridge mid-channel                         1    10.333333
# Poughkeepsie Drinking Water Intake            1    11.555556
# Haverstraw Bay mid-channel                    1    12.166667
# Marlboro Landing                              1    12.611111
# Little Stony Point                            1    12.777778
# Yonkers mid-channel                           1    14.842105
# Stony Point mid-channel                       1    15.611111
# Cold Spring Harbor                            1    18.333333
#
# [8 rows x 2 columns]

# %%
worst_readings = river_entero[river_entero['Site'].isin(worst.index)]
worst_readings = worst_readings[river_entero['Date'] >= datetime(2011,01,01)]
# Out:
# /Users/JL/anaconda/envs/monitoring/lib/python2.7/site-packages/pandas/core/frame.py:1663: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
worst_readings
# Out:
#                               Site                Date  EnteroCount  \
# 36       Mohawk River at Waterford 2012-07-21 00:00:00         3750
# 39       Mohawk River at Waterford 2013-10-21 00:00:00          130
# 40       Mohawk River at Waterford 2013-09-21 00:00:00          830
# 41       Mohawk River at Waterford 2013-08-19 00:00:00         1733
# 42       Mohawk River at Waterford 2013-07-21 00:00:00           64
# 43       Mohawk River at Waterford 2013-06-24 00:00:00         1300
# 44       Mohawk River at Waterford 2013-06-04 00:00:00          461
# 45       Mohawk River at Waterford 2012-10-15 00:00:00          770
# 46       Mohawk River at Waterford 2012-09-15 00:00:00         1300
# 47       Mohawk River at Waterford 2012-08-18 00:00:00          461
# 49       Mohawk River at Waterford 2012-06-16 00:00:00         1023
# 50       Mohawk River at Waterford 2012-05-20 00:00:00          238
# 51       Mohawk River at Waterford 2011-10-16 00:00:00         2420
# 52       Mohawk River at Waterford 2011-09-19 00:00:00           68
# 53       Mohawk River at Waterford 2011-08-21 00:00:00          142
# 54       Mohawk River at Waterford 2011-07-14 00:00:00           33
# 55       Mohawk River at Waterford 2011-07-02 00:00:00            4
# 56       Mohawk River at Waterford 2011-05-19 00:00:00           96
# 181   Dunn Memorial Bridge- Albany 2012-06-16 00:00:00           17
# 184   Dunn Memorial Bridge- Albany 2013-10-21 00:00:00          134
# 185   Dunn Memorial Bridge- Albany 2013-09-21 00:00:00           46
# 186   Dunn Memorial Bridge- Albany 2013-08-19 00:00:00           29
# 187   Dunn Memorial Bridge- Albany 2013-07-21 00:00:00           19
# 188   Dunn Memorial Bridge- Albany 2013-06-24 00:00:00         1553
# 189   Dunn Memorial Bridge- Albany 2013-06-04 00:00:00         1553
# 190   Dunn Memorial Bridge- Albany 2012-10-15 00:00:00          411
# 191   Dunn Memorial Bridge- Albany 2012-09-15 00:00:00          211
# 192   Dunn Memorial Bridge- Albany 2012-08-18 00:00:00           17
# 194   Dunn Memorial Bridge- Albany 2012-07-21 00:00:00            3
# 195   Dunn Memorial Bridge- Albany 2012-05-20 00:00:00          187
# 196   Dunn Memorial Bridge- Albany 2011-10-16 00:00:00         3750
# 197   Dunn Memorial Bridge- Albany 2011-09-19 00:00:00          687
# 198   Dunn Memorial Bridge- Albany 2011-08-21 00:00:00           34
# 199   Dunn Memorial Bridge- Albany 2011-07-14 00:00:00           76
# 200   Dunn Memorial Bridge- Albany 2011-07-02 00:00:00           84
# 201   Dunn Memorial Bridge- Albany 2011-05-19 00:00:00          770
# 1322          Newburgh Launch Ramp 2012-05-18 00:00:00            8
# 1329          Newburgh Launch Ramp 2011-05-18 00:00:00          921
# 1330          Newburgh Launch Ramp 2011-06-29 00:00:00          727
# 1331          Newburgh Launch Ramp 2011-07-17 00:00:00           12
# 1332          Newburgh Launch Ramp 2011-08-18 00:00:00          921
# 1333          Newburgh Launch Ramp 2011-09-17 00:00:00          125
# 1334          Newburgh Launch Ramp 2011-10-18 00:00:00          411
# 1335          Newburgh Launch Ramp 2012-06-14 00:00:00           37
# 1337          Newburgh Launch Ramp 2012-07-19 00:00:00           93
# 1338          Newburgh Launch Ramp 2012-08-15 00:00:00          365
# 1339          Newburgh Launch Ramp 2012-09-13 00:00:00           33
# 1340          Newburgh Launch Ramp 2012-10-14 00:00:00           58
# 1341          Newburgh Launch Ramp 2013-06-02 00:00:00          194
# 1342          Newburgh Launch Ramp 2013-06-22 00:00:00           49
# 1343          Newburgh Launch Ramp 2013-07-19 00:00:00         1733
# 1344          Newburgh Launch Ramp 2013-08-17 00:00:00          131
# 1345          Newburgh Launch Ramp 2013-09-20 00:00:00           88
# 1346          Newburgh Launch Ramp 2013-10-18 00:00:00          365
# 2469          Upper Sparkill Creek 2012-07-14 00:00:00         3750
# 2480          Upper Sparkill Creek 2012-12-10 00:00:00         2420
# 2489          Upper Sparkill Creek 2012-11-08 00:00:00         1935
# 2490          Upper Sparkill Creek 2012-11-06 00:00:00          197
# 2491          Upper Sparkill Creek 2012-10-06 00:00:00         3750
# 2492          Upper Sparkill Creek 2012-09-08 00:00:00         3750
#                                ...                 ...          ...
#
#       FourDayRainTotal  SampleCount pass_safety
# 36                 0.2           35       False
# 39                 0.2           35       False
# 40                 0.0           35       False
# 41                 0.0           35       False
# 42                 0.0           35        True
# 43                 1.4           35       False
# 44                 1.2           35       False
# 45                 1.4           35       False
# 46                 0.1           35       False
# 47                 0.3           35       False
# 49                 0.2           35       False
# 50                 0.0           35       False
# 51                 1.5           35       False
# 52                 0.1           35        True
# 53                 0.4           35       False
# 54                 0.3           35        True
# 55                 2.1           35        True
# 56                 1.6           35        True
# 181                0.2           38        True
# 184                0.2           38       False
# 185                0.0           38        True
# 186                0.0           38        True
# 187                0.0           38        True
# 188                1.4           38       False
# 189                1.2           38       False
# 190                1.4           38       False
# 191                0.1           38       False
# 192                0.3           38        True
# 194                0.2           38        True
# 195                0.0           38       False
# 196                1.5           38       False
# 197                0.1           38       False
# 198                0.4           38        True
# 199                0.3           38        True
# 200                2.1           38        True
# 201                1.6           38       False
# 1322               0.3           38        True
# 1329               2.1           38       False
# 1330               0.5           38       False
# 1331               0.0           38        True
# 1332               0.8           38       False
# 1333               0.1           38       False
# 1334               0.1           38       False
# 1335               0.5           38        True
# 1337               0.2           38        True
# 1338               0.4           38       False
# 1339               0.0           38        True
# 1340               0.0           38        True
# 1341               0.0           38       False
# 1342               0.0           38        True
# 1343               0.1           38       False
# 1344               0.0           38       False
# 1345               0.0           38        True
# 1346               0.0           38       False
# 2469               0.0          165       False
# 2480               0.6          165       False
# 2489               0.1          165       False
# 2490               0.0          165       False
# 2491               0.8          165       False
# 2492               0.8          165       False
#                    ...          ...         ...
#
# [135 rows x 6 columns]

# %%
best_readings = river_entero[river_entero['Site'].isin(best.index)]
best_readings = best_readings[river_entero['Date'] >= datetime(2011,01,01)]

# %%
p = ggplot(worst_readings, aes(x='Date', y='EnteroCount')) + geom_point() + scale_x_date(labels='%m %y') 
p = p  + geom_hline(y=110,color='blue') + geom_hline(y=5000,color='white') + geom_hline(y=-1500,color='white')
p + facet_wrap('Site', nrow=2)
# Out:
# <ggplot: (283847181)>

# %%
worst['Site_Name'] = worst.index
worst['Site_Name'] = worst['Site_Name'].str[0:12]
p2 = ggplot(worst.reset_index(), aes(x='Site_Name', y='pass_safety')) + geom_bar(aes(weight='pass_safety', fill='steelblue'))
p2 + scale_y_continuous('Water Quality Pass Rate')
# Out:
# <ggplot: (278039229)>

# %%
best['Site_Name'] = best.index
best['Site_Name'] = best['Site_Name'].str[0:12]
p2 = ggplot(best.reset_index(), aes(x='Site_Name', y='pass_safety')) + geom_bar(aes(weight='pass_safety', fill='steelblue'))
p2 + scale_y_continuous('Water Quality Pass Rate')
# Out:
# <ggplot: (278039221)>

# %% [markdown]
# # 2 The testing of water quality can be sporadic. Which sites have been tested most regularly? Which ones have long gaps between tests? Pick out 5-10 sites and visually compare how regularly their water quality is tested.

# %% [markdown]
# Time distance between events is really difficult to convey, especially when we are aggregating data. We'll attempt to handle it using histograms

# %%
river_entero.sort(['Site', 'Date'], inplace=True)
river_entero.reset_index(inplace=True)

# %%
river_entero['days_between_samples'] = river_entero['Date'].diff()
river_entero[60:70]
# Out:
#     index                  Site                Date  EnteroCount  \
# 60   2903        125th St. Pier 2013-05-31 00:00:00            6
# 61   2904        125th St. Pier 2013-06-19 00:00:00           41
# 62   2905        125th St. Pier 2013-07-17 00:00:00           10
# 63   2906        125th St. Pier 2013-08-14 00:00:00           31
# 64   2907        125th St. Pier 2013-09-18 00:00:00           41
# 65   2908        125th St. Pier 2013-10-16 00:00:00          201
# 66   3013  79th St. mid-channel 2006-09-26 00:00:00            6
# 67   3012  79th St. mid-channel 2006-10-18 00:00:00           30
# 68   3011  79th St. mid-channel 2006-11-10 00:00:00          143
# 69   3010  79th St. mid-channel 2007-04-18 00:00:00          205
#
#     FourDayRainTotal  SampleCount pass_safety  days_between_samples
# 60               0.5           66        True    204 days, 00:00:00
# 61               0.2           66        True     19 days, 00:00:00
# 62               0.0           66        True     28 days, 00:00:00
# 63               1.0           66        True     28 days, 00:00:00
# 64               0.0           66        True     35 days, 00:00:00
# 65               0.0           66       False     28 days, 00:00:00
# 66               0.1           49        True  -2577 days, 00:00:00
# 67               1.1           49        True     22 days, 00:00:00
# 68               3.6           49       False     23 days, 00:00:00
# 69               8.5           49       False    159 days, 00:00:00
#
# [10 rows x 8 columns]

# %%
river_entero['days_between_samples'][river_entero['days_between_samples'] < 1] = None
river_entero[60:70]
# Out:
#     index                  Site                Date  EnteroCount  \
# 60   2903        125th St. Pier 2013-05-31 00:00:00            6
# 61   2904        125th St. Pier 2013-06-19 00:00:00           41
# 62   2905        125th St. Pier 2013-07-17 00:00:00           10
# 63   2906        125th St. Pier 2013-08-14 00:00:00           31
# 64   2907        125th St. Pier 2013-09-18 00:00:00           41
# 65   2908        125th St. Pier 2013-10-16 00:00:00          201
# 66   3013  79th St. mid-channel 2006-09-26 00:00:00            6
# 67   3012  79th St. mid-channel 2006-10-18 00:00:00           30
# 68   3011  79th St. mid-channel 2006-11-10 00:00:00          143
# 69   3010  79th St. mid-channel 2007-04-18 00:00:00          205
#
#     FourDayRainTotal  SampleCount pass_safety  days_between_samples
# 60               0.5           66        True    204 days, 00:00:00
# 61               0.2           66        True     19 days, 00:00:00
# 62               0.0           66        True     28 days, 00:00:00
# 63               1.0           66        True     28 days, 00:00:00
# 64               0.0           66        True     35 days, 00:00:00
# 65               0.0           66       False     28 days, 00:00:00
# 66               0.1           49        True                   NaT
# 67               1.1           49        True     22 days, 00:00:00
# 68               3.6           49       False     23 days, 00:00:00
# 69               8.5           49       False    159 days, 00:00:00
#
# [10 rows x 8 columns]

# %%
river_entero['days_between_samples'] = river_entero['days_between_samples'].astype('timedelta64[D]')

# %%
ggplot(river_entero, aes(x='days_between_samples')) + geom_histogram(binwidth=10)
# Out:
# <ggplot: (278718117)>

# %% [markdown]
# It looks like there are two patterns of sampling: every month and about every 7 months (probably for places that are likely to freeze!) Let's compare a couple of places

# %%
new_worst = river_entero[river_entero['Site'].isin(worst.index)]

# %%
ggplot(new_worst, aes(x='days_between_samples')) + geom_histogram(binwidth=10) + facet_wrap('Site') + geom_vline(x=280, color='white')
# Out:
# <ggplot: (277485989)>

# %% [markdown]
# # 3 Is there a relationship between the amount of rain and water quality?  Show this relationship graphically. If you can, estimate the effect of rain on quality at different sites and create a visualization to compare them

# %% [markdown]
# classic scatterplot question: comparing two values to find a relationship

# %%
p = ggplot(new_worst, aes(x='FourDayRainTotal', y='EnteroCount')) + geom_point(alpha=.1) 
p + ylim(0,4000) + xlim(-1,9) + stat_smooth( color='red', method='loess')
# Out:
# <ggplot: (278693421)>

# %% [markdown]
# Lots of problems here: too much data, overplotting. We can take medians by bin

# %%
new_worst['rainfall_bin'] = (4 * new_worst['FourDayRainTotal']).round()/4

# %%
rain_sum = new_worst.groupby('rainfall_bin').median()
rain_sum['rainfall'] = rain_sum.index
rain_sum
# Out:
#                index  EnteroCount  FourDayRainTotal  SampleCount pass_safety  \
# rainfall_bin
# 0.00          2450.5         88.0              0.00           57        True
# 0.25          2424.5         89.0              0.20           50        True
# 0.50          2492.5        146.0              0.50           50       False
# 0.75          2492.5        825.0              0.80          111       False
# 1.00          2618.5        770.0              1.05           57       False
# 1.25          2473.0        732.5              1.20           57       False
# 1.50           190.0        770.0              1.50           38       False
# 1.75          2487.0        696.5              1.70          165       False
# 2.00          2458.0        842.0              2.00           50       False
# 2.25          2474.5       3750.0              2.30          165       False
# 2.50          2866.0       3750.0              2.50          111       False
# 2.75           212.0       1031.0              2.80           38       False
# 3.25          2452.0       1500.0              3.20          165       False
# 3.50          2855.0        760.0              3.60           50       False
# 4.75          2388.0        685.0              4.80          165       False
# 6.50          2825.0        613.0              6.40           50       False
# 8.50          2854.0        894.0              8.50           50       False
#
#               days_between_samples rainfall
# rainfall_bin
# 0.00                          23.0        0
# 0.25                          27.0     0.25
# 0.50                          27.0      0.5
# 0.75                          22.5     0.75
# 1.00                          27.5        1
# 1.25                          29.0     1.25
# 1.50                          23.0      1.5
# 1.75                           4.0     1.75
# 2.00                          24.5        2
# 2.25                          21.0     2.25
# 2.50                          18.0      2.5
# 2.75                          24.0     2.75
# 3.25                           9.0     3.25
# 3.50                          23.0      3.5
# 4.75                           1.0     4.75
# 6.50                          28.0      6.5
# 8.50                         126.0      8.5
#
# [17 rows x 7 columns]

# %%
ggplot(rain_sum,aes(x='rainfall', y='EnteroCount')) + geom_bar(aes(weight='EnteroCount', fill='blue'))
#rain_sum.reset_index()
# Out:
# <ggplot: (278015189)>

# %% [markdown]
# wow: that's noticable. The median Enter count goes way up after .75 inches of rain, with spikes once it gets over 2 inches. It is unclear whether those are outliers though: let's dig in more.

# %%
rain_sum_site = new_worst.groupby(['Site','rainfall_bin']).median()
rain_sum_site['rainfall'] = rain_sum_site.index.get_level_values('rainfall_bin')
rain_sum_site['Site'] = rain_sum_site.index.get_level_values('Site')
rain_sum_site[0:3]
# Out:
#                                            index  EnteroCount  \
# Site                         rainfall_bin
# Dunn Memorial Bridge- Albany 0.00            200         49.5
#                              0.25            194         25.0
#                              0.50            214         84.0
#
#                                            FourDayRainTotal  SampleCount  \
# Site                         rainfall_bin
# Dunn Memorial Bridge- Albany 0.00                       0.0           38
#                              0.25                       0.2           38
#                              0.50                       0.5           38
#
#                                            pass_safety  days_between_samples  \
# Site                         rainfall_bin
# Dunn Memorial Bridge- Albany 0.00                    1                    29
#                              0.25                    1                    29
#                              0.50                    1                    28
#
#                                           rainfall  \
# Site                         rainfall_bin
# Dunn Memorial Bridge- Albany 0.00                0
#                              0.25             0.25
#                              0.50              0.5
#
#                                                                    Site
# Site                         rainfall_bin
# Dunn Memorial Bridge- Albany 0.00          Dunn Memorial Bridge- Albany
#                              0.25          Dunn Memorial Bridge- Albany
#                              0.50          Dunn Memorial Bridge- Albany
#
# [3 rows x 8 columns]

# %%
p4 = ggplot(rain_sum_site, aes(x='rainfall', y='EnteroCount')) + geom_point() 
p4 + scale_x_continuous() + geom_vline(x=9, color='white') + facet_wrap('Site')
# Out:
# <ggplot: (279942905)>

# %% [markdown]
# It does not look like there is a local peak at 2-2.5 inches of rain: likely due to issues with tracking data at Upper Sparkill and some random noise.
